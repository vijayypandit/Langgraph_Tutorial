# %%
from langchain_groq import ChatGroq
from langgraph.graph import StateGraph ,START, END
from typing import TypedDict , Annotated , operator
from pydantic import BaseModel, Field

from dotenv import load_dotenv
load_dotenv(override=True)
import os
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model=ChatGroq(model="llama-3.1-8b-instant")

# %%
class EvaluationSchema(BaseModel):

    feedback:str = Field(description="Detailed feedback on the essay.")
    score:int =Field(description="Score out of 10",ge=0,le=10)

# %%
structured_Model = model.with_structured_output(EvaluationSchema)

# %%
essay = """
The Role of AI in India

Artificial intelligence (AI) is rapidly transforming India’s economy, society, and governance. As one of the world’s fastest-growing digital ecosystems, India has the opportunity to harness AI to accelerate development, improve public services, and expand opportunities for its citizens. At the same time, the nation faces important challenges related to ethics, inclusion, and data privacy. This essay explores the role of AI in India by examining its economic impact, social applications, government initiatives, and the challenges the country must address to realize AI’s full promise.

AI’s economic role in India is already evident across multiple sectors. In agriculture, AI-driven tools help farmers optimize crop yields, manage water use, and detect pest infestations early. Startups are creating mobile applications that analyze imagery from inexpensive smartphones to diagnose crop diseases and recommend fertilizers. Precision agriculture powered by AI can help smallholder farmers increase productivity while reducing cost, which is critical for a nation where agriculture employs a large share of the population.

Manufacturing and industry are also becoming more efficient through AI. Indian factories are increasingly applying machine learning to improve quality control, predictive maintenance, and supply chain management. This digital transformation supports the government’s “Make in India” initiative by making domestic production more competitive. Artificial intelligence can help companies identify inefficiencies in production lines, reduce downtime through predictive analytics, and plan inventory more accurately, all of which support economic growth and job creation.

The information technology sector itself benefits from AI as a major driver of innovation. Indian software firms and startups are building AI products for global customers, from natural language processing tools to computer vision systems. India’s strong talent base in mathematics, engineering, and computer science positions it well to contribute to global AI research and deployment. At the same time, the AI economy is creating new entrepreneurship opportunities in fintech, health tech, edtech, and other knowledge-driven industries.

AI also has a growing social impact in India. In education, AI-powered learning platforms are offering personalized instruction to learners across urban and rural communities. Adaptive learning systems can tailor course material to each student’s pace, identify areas of difficulty, and provide remedial support. This is especially important in India, where schools have widely varying resources and teacher availability. By delivering customized learning experiences, AI can help narrow gaps and support greater educational equity.

Healthcare is another area where AI can drive meaningful social change. AI-enabled diagnostic systems can analyze medical scans, predict disease risk, and assist physicians with treatment planning. In remote or underserved regions, these systems can help bridge gaps in access to specialist care. For example, AI tools that screen for diabetic retinopathy, tuberculosis, and cardiovascular disease can bring early detection to communities that lack advanced medical infrastructure. AI also supports public health by modeling disease outbreaks, identifying areas of need, and optimizing resource allocation.

The public sector in India is investing heavily in AI to improve governance and public services. The government has launched various initiatives aimed at nurturing AI research, supporting startups, and integrating AI into citizen services. National policies emphasize the importance of data-driven decision-making in areas such as smart cities, traffic management, energy efficiency, and disaster response. AI-powered systems are used in smart cities to manage traffic flows, monitor air quality, and optimize water distribution, improving quality of life for urban residents.

India’s Digital India program provides a broader framework for AI adoption by improving digital infrastructure and connectivity. With expanded broadband access and mobile penetration, more citizens can interact with digital services, enabling AI-based platforms to reach a larger audience. This connectivity is essential for deploying AI solutions that rely on mobile devices, cloud services, and digital identity systems. For example, the Aadhaar digital identity program underpins many AI-backed welfare delivery systems by ensuring services are targeted accurately and securely.

AI can also support financial inclusion in India. Fintech platforms are using AI to assess creditworthiness, detect fraud, and provide personalized financial advice. By analyzing transaction histories, mobile usage patterns, and alternative data sources, AI systems can approve loans for people who lack traditional credit records. This expands access to formal financial services for millions of Indians and supports entrepreneurship and small business growth.

While AI offers significant promise, India must address key challenges to ensure its adoption is widespread, fair, and sustainable. One major concern is digital inequality. Access to AI-driven services depends on internet connectivity, digital literacy, and economic resources. Rural areas and marginalized communities may be left behind if AI solutions are not designed with inclusion in mind. To prevent widening disparities, policymakers and businesses must prioritize affordable access, language diversity, and local relevance in AI applications.

Data privacy and ethical use of AI are also critical issues. As AI systems increasingly rely on personal and sensitive data, India must develop robust frameworks to protect citizens’ rights. This includes creating clear regulations for consent, data collection, and algorithmic transparency. Without strong privacy protections, there is a risk that AI could be misused for surveillance, biased decision-making, or unfair profiling. A balanced approach is needed to support innovation while safeguarding individual freedoms.

Another challenge is the need for skilled talent. Although India has a large technology workforce, building and scaling AI effectively requires expertise in machine learning, data science, and domain-specific knowledge. Education and training programs must evolve to teach AI skills at scale. This includes updating curricula in universities, supporting vocational training, and promoting lifelong learning opportunities. By investing in human capital, India can ensure that its workforce is prepared for the jobs AI creates and can compete in a global market.

Algorithmic fairness is a further challenge. AI systems trained on biased or incomplete data can produce unfair outcomes. In India, where social inequalities are deep and diverse, it is especially important to prevent AI from reinforcing existing biases. This requires careful evaluation of data sources, inclusive design practices, and mechanisms to detect and correct bias. Stakeholders should engage with civil society, academia, and communities to ensure AI systems reflect India’s values of fairness and equity.

India’s potential as an AI leader also depends on collaboration between government, industry, academia, and civil society. Public-private partnerships can accelerate deployment of AI in priority sectors while leveraging research expertise. Academic institutions can contribute foundational research, while startups and established firms can convert innovation into products. Civil society groups play a vital role in advocating for ethical practices and ensuring AI is responsive to citizen needs.

To maximize AI’s benefits, India can build an ecosystem that supports responsible innovation. This includes investing in research infrastructure, funding AI startups, and creating innovation hubs. Policies should encourage experimentation while providing guidance on safety, accountability, and social impact. Open data initiatives and shared research platforms can enable broader participation and reduce barriers to entry for early-stage innovators.

The role of AI in India is not limited to economic growth; it also includes strengthening democracy and civic engagement. AI tools can help analyze public feedback, monitor governance outcomes, and improve transparency in service delivery. When used responsibly, AI can empower citizens by making information more accessible and enabling better participation in policymaking. For example, natural language processing can make government communications available in regional languages, while data analytics can help identify areas where public services are underperforming.

India’s AI journey will be shaped by its cultural diversity and democratic ethos. AI solutions that work in India must be sensitive to local languages, regional conditions, and social norms. Success hinges on grounding technology in the lived realities of India’s citizens rather than imposing one-size-fits-all models. This means designing AI systems for local languages, low-bandwidth contexts, and the practical needs of diverse communities.

Looking ahead, the role of AI in India will likely grow across every major area of life. Education will become more personalized, healthcare more proactive, agriculture more efficient, and cities more livable. AI will also enable new forms of entrepreneurship and creative expression. Yet the future depends on how India balances innovation with social responsibility. Policymakers, businesses, and citizens must work together to build AI systems that are inclusive, transparent, and accountable.

In conclusion, AI in India is a powerful force for development and transformation. It can boost economic productivity, improve public services, and expand access to education and healthcare. At the same time, India must address challenges such as digital inequality, data privacy, ethical bias, and skills gaps. By investing in inclusive infrastructure, ethical frameworks, and human capital, India can ensure AI serves the interests of all its people. The responsible deployment of AI can help India achieve sustainable growth, social equity, and a future where technology amplifies the country’s strengths rather than reproducing its challenges.

"""

# %%
# prompt = f'Evaluate the language quality of the following essay and provide detailed feedback on its strengths and weaknesses. Additionally, assign a score out of 10 \n {essay}'
prompt = f'Evaluate the language quality of the following essay and provide detailed feedback on its strengths and weaknesses. Additionally, assign a score out of 10.\n IMPORTANT: Respond ONLY with a JSON object matching this schema exactly feedback and score:\n {essay}'
structured_Model.invoke(prompt).feedback
# Out:
# "The essay provides a comprehensive overview of the role of AI in India, discussing its economic impact, social applications, government initiatives, and challenges. The writer demonstrates a clear understanding of the subject matter and presents well-supported arguments. However, the essay could benefit from more nuanced analysis and consideration of counterarguments. Additionally, some sections feel a bit repetitive, and the writing could be more engaging throughout. Overall, the essay is well-structured and effectively conveys the author's perspective on AI in India. The writer's use of examples and data adds credibility to the essay and helps to illustrate the potential benefits and challenges of AI in India. However, the essay could benefit from more attention to detail in terms of grammar, punctuation, and sentence structure. "

# %%
class UPSCState(TypedDict):
    essay:str
    language_feedback:str
    analysis_feedback:str
    clarity_feedback:str
    overall_feedback:str
    individual_scores:Annotated[list[int],operator.add]
    avg_scores:float

# %%
def evaluate_language(state:UPSCState):
    prompt = f'Evaluate the language quality of the following essay and provide detailed feedback on its strengths and weaknesses. Additionally, assign a score out of 10.\n IMPORTANT: Respond ONLY with a JSON object matching this schema exactly:\n {state["essay"]}'

    output= structured_Model.invoke(prompt)
    return {'language_feedback':output.feedback,'individual_scores':[output.score]}

def evaluate_analysis(state:UPSCState):
    prompt = f'Evaluate the depth of analysis of the following essay and provide detailed feedback on its strengths and weaknesses. Additionally, assign a score out of 10.\n IMPORTANT: Respond ONLY with a JSON object matching this schema exactly:\n {state["essay"]}'

    output= structured_Model.invoke(prompt)
    return {'analysis_feedback':output.feedback,'individual_scores':[output.score]}

def evaluate_thought(state:UPSCState):
    prompt = f'Evaluate the clarity of thought of the following essay and provide detailed feedback on its strengths and weaknesses. Additionally, assign a score out of 10.\n IMPORTANT: Respond ONLY with a JSON object matching this schema exactly:\n {state["essay"]}'

    output= structured_Model.invoke(prompt)
    return {'clarity_feedback':output.feedback,'individual_scores':[output.score]}

# %%
def final_evaluation(state:UPSCState):

    #Summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state['language_feedback']} \n depth of analysis feedback - {state['analysis_feedback']} \n clarity feedback - {state['clarity_feedback']}'

    overall_feedback = model.invoke(prompt)

    #Avg calculation
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])
    return {'overall_feedback' : overall_feedback,'avg_scores':avg_score}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('final_evaluation',final_evaluation)

graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')

graph.add_edge('evaluate_language','final_evaluation')
graph.add_edge('evaluate_analysis','final_evaluation')
graph.add_edge('evaluate_thought','final_evaluation')
graph.add_edge('final_evaluation',END)

workflow = graph.compile()
workflow

# %%
initial_state = {
    'essay' : essay
}
workflow.invoke(initial_state)
# Out:
# {'essay': '\nThe Role of AI in India\n\nArtificial intelligence (AI) is rapidly transforming India’s economy, society, and governance. As one of the world’s fastest-growing digital ecosystems, India has the opportunity to harness AI to accelerate development, improve public services, and expand opportunities for its citizens. At the same time, the nation faces important challenges related to ethics, inclusion, and data privacy. This essay explores the role of AI in India by examining its economic impact, social applications, government initiatives, and the challenges the country must address to realize AI’s full promise.\n\nAI’s economic role in India is already evident across multiple sectors. In agriculture, AI-driven tools help farmers optimize crop yields, manage water use, and detect pest infestations early. Startups are creating mobile applications that analyze imagery from inexpensive smartphones to diagnose crop diseases and recommend fertilizers. Precision agriculture powere
# ...
